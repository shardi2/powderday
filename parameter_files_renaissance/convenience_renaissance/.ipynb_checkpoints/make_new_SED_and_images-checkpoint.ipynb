# %%
import ytree
import os
a = ytree.load('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/arbor/arbor.h5')
a.field_list
# Out:
# ['scale_factor',
#  'uid',
#  'desc_scale',
#  'desc_uid',
#  'num_prog',
#  'pid',
#  'upid',
#  'desc_pid',
#  'phantom',
#  'sam_Mvir',
#  'mass',
#  'virial_radius',
#  'scale_radius',
#  'velocity_dispersion',
#  'mmp?',
#  'scale_of_last_MM',
#  'vmax',
#  'position_x',
#  'position_y',
#  'position_z',
#  'velocity_x',
#  'velocity_y',
#  'velocity_z',
#  'angular_momentum_x',
#  'angular_momentum_y',
#  'angular_momentum_z',
#  'spin_parameter',
#  'Breadth_first_ID',
#  'Depth_first_ID',
#  'Tree_root_ID',
#  'halo_id',
#  'Snap_idx',
#  'Next_coprogenitor_depthfirst_ID',
#  'Last_progenitor_depthfirst_ID',
#  'Last_mainleaf_depthfirst_ID',
#  'Tidal_Force',
#  'Tidal_ID',
#  'Rs_Klypin',
#  'Mvir_all',
#  'M200b',
#  'M200c',
#  'M500c',
#  'M2500c',
#  'Xoff',
#  'Voff',
#  'Spin_Bullock',
#  'b_to_a',
#  'c_to_a',
#  'A[x]',
#  'A[y]',
#  'A[z]',
#  'b_to_a(500c)',
#  'c_to_a(500c)',
#  'A[x](500c)',
#  'A[y](500c)',
#  'A[z](500c)',
#  'T_|U|',
#  'M_pe_Behroozi',
# ...

# %%
particle_num = 1000000

# %%
#plotting the SED
x = 0
num = 6
for i in range(0, a.size, 1):
    if a['stellar_mass'][i] != 0:
        with open('sed_plot.py', 'r') as ogfile, open('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/convenience_renaissance/sed_plot_'+str(x)+'_'+str(particle_num)+'.py', 'w') as newfile:
            for line in ogfile:
                if line == "run = '/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_10000/pd_sed/example.0000.rtout.sed'\n":
                    output_num = i
                    output_num = '{:04d}'.format(output_num)
                    newfile.write("run = '/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/halo_"+str(x)+"/example."+str(output_num)+".rtout.sed'\n")
                elif line == "fig.savefig('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_10000/pd_sed/sed_0000.png')\n":
                    newfile.write("fig.savefig('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/pd_sed/sed_"+str(output_num)+".png')\n")
                elif line == 'f = h5py.File("/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/final_dataset_halo_catalog.hdf5", "a")\n':
                    newfile.write('f = h5py.File("/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/final_dataset_halo_catalog.hdf5", "a")\n')
                elif line == "if 'halo_0/photons_1e4/SED_wav' in f:\n":
                    newfile.write("if 'halo_0/photons_1e"+str(num)+"/SED_wav' in f:\n")
                elif line == "    del f['halo_0/photons_1e4/SED_wav']\n":
                    newfile.write("    del f['halo_"+str(i)+"/photons_1e"+str(num)+"/SED_wav']\n")
                elif line == "    f.create_dataset('halo_0/photons_1e4/SED_wav', data=wav)\n":
                    newfile.write("    f.create_dataset('halo_"+str(i)+"/photons_1e"+str(num)+"/SED_wav', data=wav)\n")
                elif line == "if 'halo_0/photons_1e4/SED_flux' in f:\n":
                    newfile.write("if 'halo_"+str(i)+"/photons_1e"+str(num)+"/SED_flux' in f:\n")
                elif line == "    del f['halo_0/photons_1e4/SED_flux']\n":
                    newfile.write("    del f['halo_"+str(i)+"/photons_1e"+str(num)+"/SED_flux']")
                elif line == "    f.create_dataset('halo_0/photons_1e4/SED_flux', data=flux)\n":
                    newfile.write("    f.create_dataset('halo_"+str(i)+"/photons_1e"+str(num)+"/SED_flux', data=flux)\n")
                else:
                    newfile.write(line)
            x += 1
# Out:
#   Cell In[3], line 26
#     newfile.write("    f.create_dataset('halo_"+str()/photons_1e4/SED_flux', data=flux)")
#                                                                                          ^
# SyntaxError: EOL while scanning string literal

# %%
#making the single wavelength image
x = 0
num = 6
for i in range(0, a.size, 1):
    if a['stellar_mass'][i] != 0:
        with open('make_image_single_wavelength.py', 'r') as ogfile, open('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/convenience_renaissance/make_image_single_wavelength_'+str(x)+'_'+str(particle_num)+'.py', 'w') as newfile:
            for line in ogfile:
                if line == "m = ModelOutput('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_10000/halo_0/example.0000.rtout.image')\n":
                    output_num = i
                    output_num = '{:04d}'.format(output_num)
                    newfile.write("m = ModelOutput('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/example."+str(output_num)+".rtout.image')\n")
                elif line == "fig.savefig('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_100000/pd_image/pd_image_100000.png', bbox_inches='tight', dpi=150)\n":
                    newfile.write("fig.savefig('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/pd_image/pd_image_"+str(output_num)+".png', bbox_inches='tight', dpi=150)")
                elif line == "if 'halo_0/photons_1e6/image' in f:\n":
                    newfile.write("if 'halo_"+str(i)+"/photons_1e"+str(num)+"/image' in f:\n")
                elif line == "    del f['halo_0/photons_1e6/image']\n":
                    newfile.write("    del f['halo_"+str(i)+"/photons_1e"+str(num)+"/image']")
                elif line == "    f.create_dataset('halo_0/photons_1e6/image', data=np.log10(image.val[0, :, :, iwav]))\n":
                    newfile.write("    f.create_dataset('halo_"+str(i)+"/photons_1e"+str(num)+"/image', data=np.log10(image.val[0, :, :, iwav]))\n")
                else:
                    newfile.write(line)
            #newfile.write("\n\nf.create_dataset('halo_"+str(i)+"/"+str(particle_num)+"/image', data=final_image_log)")
            x += 1

# %%
#calculating the UV absolute magnitude
x = 0
num = 6
for i in range(0, a.size, 1):
    if a['stellar_mass'][i] != 0:
        with open('abs_mag.py', 'r') as ogfile, open('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/convenience_renaissance/abs_mag_'+str(x)+'_'+str(particle_num)+'.py', 'w') as newfile:
            for line in ogfile:
                if line == "run = '/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_10000/pd_sed/example.0000.rtout.sed'\n":
                    output_num = i
                    output_num = '{:04d}'.format(output_num)
                    newfile.write("run = '/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/halo_"+str(x)+"/example."+str(output_num)+".rtout.sed'\n")
                elif line == 'f = h5py.File("/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/final_dataset_halo_catalog.hdf5", "a")\n':
                    newfile.write('f = h5py.File("/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/final_dataset_halo_catalog.hdf5", "a")\n')
                elif line == "if 'halo_0/photons_1e4/absolute_magnitude_UV' in f:\n":
                    newfile.write("if 'halo_0/photons_1e"+str(num)+"/absolute_magnitude_UV' in f:\n")
                elif line == "    del f['halo_0/photons_1e4/absolute_magnitude_UV']\n":
                    newfile.write("    del f['halo_"+str(i)+"/photons_1e"+str(num)+"/absolute_magnitude_UV']\n")
                elif line == "    f.create_dataset('halo_0/photons_1e4/absolute_magnitude_UV', data=ab_mag_UV)\n":
                    newfile.write("    f.create_dataset('halo_"+str(i)+"/photons_1e"+str(num)+"/absolute_magnitude_UV', data=ab_mag_UV)\n")
                else:
                    newfile.write(line)
            x += 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 x = 0
#       2 num = 6
# ----> 3 for i in range(0, a.size, 1):
#       4     if a['stellar_mass'][i] != 0:
#       5         with open('abs_mag.py', 'r') as ogfile, open('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/convenience_renaissance/abs_mag_'+str(x)+'_'+str(particle_num)+'.py', 'w') as newfile:
#
# NameError: name 'a' is not defined

# %%
#calculating the apparent magnitude 
x = 0
num = 6
for i in range(0, a.size, 1):
    if a['stellar_mass'][i] != 0:
        with open('app_mag.py', 'r') as ogfile, open('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/convenience_renaissance/app_mag_'+str(x)+'_'+str(particle_num)+'.py', 'w') as newfile:
            for line in ogfile:
                if line == "run = '/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_10000/pd_sed/example.0000.rtout.sed'\n":
                    output_num = i
                    output_num = '{:04d}'.format(output_num)
                    newfile.write("run = '/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/halo_"+str(x)+"/example."+str(output_num)+".rtout.sed'\n")
                elif line == 'f = h5py.File("/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/final_dataset_halo_catalog.hdf5", "a")\n':
                    newfile.write('f = h5py.File("/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/final_dataset_halo_catalog.hdf5", "a")\n')
                elif line == "if 'halo_0/photons_1e4/apparent_mag' in f:\n":
                    newfile.write("if 'halo_0/photons_1e"+str(num)+"/apparent_mag' in f:\n")
                elif line == "    del f['halo_0/photons_1e4/apparent_mag']\n":
                    newfile.write("    del f['halo_"+str(i)+"/photons_1e"+str(num)+"/apparent_mag']\n")
                elif line == "    f.create_dataset('halo_0/photons_1e4/apparent_mag', data=ab_mag_UV)\n":
                    newfile.write("    f.create_dataset('halo_"+str(i)+"/photons_1e"+str(num)+"/apparent_mag', data=ab_mag_UV)\n")
                else:
                    newfile.write(line)
            x += 1

# %%
#calculating the half light radius - finish fixing this
x = 0
num = 6
for i in range(0, a.size, 1):
    if a['stellar_mass'][i] != 0:
        with open('half_light.py', 'r') as ogfile, open('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/convenience_renaissance/half_light_'+str(x)+'_'+str(particle_num)+'.py', 'w') as newfile:
            for line in ogfile:
                if line == "m = ModelOutput('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_10000/halo_0/example.0000.rtout.image')\n":
                    output_num = i
                    output_num = '{:04d}'.format(output_num)
                    newfile.write("m = ModelOutput('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/example."+str(output_num)+".rtout.image')\n")
                elif line == 'a = ytree.load("/storage/home/hcoda1/0/jw254/data/SG64-2020/rockstar_halos-jhw/trees/tree_0_0_0.dat")\n':
                    newfile.write('a = ytree.load("/storage/home/hcoda1/0/jw254/data/RS-RP/rockstar_halos/trees/tree_0_0_0.dat")\n')
                elif line == "fig.savefig('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_100000/pd_image/pd_image_100000.png', bbox_inches='tight', dpi=150)\n":
                    newfile.write("fig.savefig('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/pd_image/pd_image_"+str(output_num)+".png', bbox_inches='tight', dpi=150)")
                elif line == "if 'halo_0/photons_1e4/half_light_rad' in f:\n":
                    newfile.write("if 'halo_"+str(i)+"/photons_1e"+str(num)+"/half_light_rad' in f:\n")
                elif line == "    del f['halo_0/photons_1e4/half_light_rad']\n":
                    newfile.write("del f['halo_"+str(i)+"/photons_1e"+str(num)+"/half_light_rad']")
                elif line == "    f.attrs['halo_0/photons_1e4/half_light_rad'] = kpc_half_light_rad\n":
                    newfile.write("    f.attrs['halo_"+str(i)+"/photons_1e"+str(num)+"/half_light_rad'] = kpc_half_light_rad\n")
                else:
                    newfile.write(line)
            #newfile.write("\n\nf.create_dataset('halo_"+str(i)+"/"+str(particle_num)+"/image', data=final_image_log)")
            x += 1

# %%
#calculating the half stellar mass radius
x = 0
num = 6
for i in range(0, a.size, 1):
    if a['stellar_mass'][i] != 0:
        with open('half_stellar_mass.py', 'r') as ogfile, open('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/convenience_renaissance/half_stellar_mass_'+str(x)+'_'+str(particle_num)+'.py', 'w') as newfile:
            for line in ogfile:
                if line == "m = ModelOutput('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_10000/halo_0/example.0000.rtout.image')\n":
                    output_num = i
                    output_num = '{:04d}'.format(output_num)
                    newfile.write("m = ModelOutput('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/example."+str(output_num)+".rtout.image')\n")
                elif line == 'a = ytree.load("/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/arbor/arbor.h5")\n':
                    newfile.write('a = ytree.load("/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/arbor/arbor.h5")\n')
                elif line == "ds = yt.load('/storage/home/hcoda1/0/jw254/data/SG64-2020/DD0125/output_0125')\n":
                    newfile.write("ds = yt.load('/storage/home/hcoda1/0/jw254/data/RS-RP/RD0041')\n")
                elif line == "fig.savefig('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_100000/pd_image/pd_image_100000.png', bbox_inches='tight', dpi=150)\n":
                    newfile.write("fig.savefig('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/summer2023/pd_test/run_renaissance_"+str(particle_num)+"/pd_image/pd_image_"+str(output_num)+".png', bbox_inches='tight', dpi=150)")
                elif line == "if 'halo_0/photons_1e4/half_light_rad' in f:\n":
                    newfile.write("if 'halo_"+str(i)+"/photons_1e"+str(num)+"/half_stellar_mass_rad' in f:\n")
                elif line == "    del f['halo_0/photons_1e4/half_light_rad']\n":
                    newfile.write("del f['halo_"+str(i)+"/photons_1e"+str(num)+"/half_stellar_mass_rad']")
                elif line == "    f.attrs['halo_0/photons_1e4/half_light_rad'] = kpc_half_light_rad\n":
                    newfile.write("    f.attrs['halo_"+str(i)+"/photons_1e"+str(num)+"/half_stellar_mass_rad'] = half_mass_rad\n")
                else:
                    newfile.write(line)
            #newfile.write("\n\nf.create_dataset('halo_"+str(i)+"/"+str(particle_num)+"/image', data=final_image_log)")
            x += 1

# %%
# import matplotlib
# matplotlib.use('Agg')

# import numpy as np
# import matplotlib.pyplot as plt
# from hyperion.model import ModelOutput
# from astropy.cosmology import Planck13
# from astropy import units as u
# from astropy import constants
# from hyperion.util.constants import pc
# import h5py
# import os
# import sys
# import ytree
# import yt
# np.set_printoptions(threshold=sys.maxsize)
# yt.enable_plugins()

# %%
# a = ytree.load('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/arbor/arbor.h5')
# a.field_list

# %%
# with h5py.File('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/convenience_renaissance/fesc-only/RP/RedshiftOutput0041-fesc-only.h5', 'r') as file:
#     #print(&quot;Keys: %s&quot; % file.keys())
#     group_keys = list(file.keys())
#     print(group_keys)
    
#     # Getting the data
#     Mstar_data = list(file['Mstar'])
#     fesc_data = list(file['fesc'])
#     center_data = list(file['center'])
#     mass_data = list(file['mass'])
#     print(fesc_data)

# %%
# f = h5py.File("final_dataset_halo_catalog.hdf5", "a")

# %%
# count = 0
# for i in range(0, a.size, 1):
#     if a['stellar_mass'][i] != 0:
#         stellar_mass = a['stellar_mass'][i].value 
#         my_halo_center = a['position'][i].value
#         #this is how john found the halo mass in his code
#         halo_mass = a['mass'][i].value + a['gas_mass'][i].value
#         if np.any(np.all(np.isclose(my_halo_center, center_data, atol=1e-4), axis=1)) == True: 
#             matches = (np.all(np.isclose(my_halo_center, center_data, atol=1e-4), axis=1))
#             john_index = np.where(matches)[0][0]
#             if (halo_mass - (halo_mass * 0.20)) <= mass_data[john_index] <= (halo_mass + (halo_mass * 0.20)):
#             #if (stellar_mass - (stellar_mass * 0.20)) <= Mstar_data[john_index] <= (stellar_mass + (stellar_mass * 0.20)):
#                 count += 1
#                 print('my index/halo number', i)
#                 print("john index", john_index)
#                 print("my stellar mass", a['stellar_mass'][i])
#                 print('john stellar mass', Mstar_data[john_index])
#                 print('my halo mass', halo_mass)
#                 print('john halo mass', mass_data[john_index])
#                 print('john fesc', fesc_data[john_index])
#                 fcov = 1 - fesc_data[john_index]
#                 print('fcov', fcov)
#                 print('\n')
                
# print(count)
#             if my_halo_center == john_halo_center and (a['stellar_mass'][i] - 100) <= Mstar_data[j] <= (a['stellar_mass'][i] + 100):
#                 if 'halo_'+str(i)+'/fesc' in f:
#                     del f['halo_'+str(i)+'/fesc']
#                     f.create_dataset('halo_'+str(i)+'/fesc', data=fesc_data[j])
#                 else:
#                     f.create_dataset('halo_'+str(i)+'/fesc', data=fesc_data[j])

# %%
# f.close()

# %%
# # my_halo_center = [0.5078616 , 0.49313354, 0.56288308]
# # my_halo_center = np.asarray(my_halo_center)
# # print(my_halo_center)
# # print(center_data[0])


# my_halo_center = a['position'][99].value
# print(my_halo_center)
# #print(center_data[0])
# #np.all(np.isclose(my_halo_center, center_data[0]))
# #np.any(np.all(my_halo_center == center_data, axis=1))
# matches = (np.all(np.isclose(my_halo_center, center_data, atol=1e-4), axis=1))
# # np.where(np.all(np.isclose(my_halo_center, center_data, atol=1e-4)))

# index = np.where(matches)[0][0]
# print(index)
# print(center_data[index])

# stellar_mass = a['stellar_mass'][99].value
# #this is how john found the halo mass in his code
# halo_mass = a['mass'][99].value + a['gas_mass'][99].value
# print("halo mass from me", halo_mass)
# print("10% halo mass", halo_mass * 0.1)
# #print(halo_mass - (halo_mass * 0.2))
# print("halo_mass from john", mass_data[index])
# print("difference", mass_data[index] - halo_mass)

# if (halo_mass - (halo_mass * 0.10)) <= mass_data[index] <= (halo_mass + (halo_mass * 0.10)):
#     print("hi")
#     print(mass_data[index])
#     print(fesc_data[index])
#     fcov = 1 - fesc_data[index]
#     print(fcov)

# %%
# list_np_arrays = np.array([[1., 1.], [1., 2.]])
# array_to_check = np.array([1., 2.])

# print(list_np_arrays)
# print(array_to_check)
# is_in_list = np.any(np.all(array_to_check == list_np_arrays, axis=1))
# print(is_in_list)

# %%
# count_1 = 0
# print(a.size)
# for i in range(0, a.size, 1):
#     if a['stellar_mass'][i] != 0:
#         count_1 += 1
# print(count_1)

# %%
# count_2 = 0
# print(len(fesc_data))
# for i in range(0, len(fesc_data), 1):
#     if fesc_data[i] != -1:
#         count_2 += 1
    
# print(count_2)

# %%
# count_3 = 0
# print(len(Mstar_data))
# for i in range(0, len(Mstar_data), 1):
#     if Mstar_data[i] != 0:
#         count_3 += 1
    
# print(count_3)

# %%
# count_4 = 0
# print(len(mass_data))
# for i in range(0, len(mass_data), 1):
#     if mass_data[i] != 0:
#         count_4 += 1
    
# print(count_4)

# %%
# coding: utf-8

# In[1]:


get_ipython().magic(u'matplotlib inline')
import matplotlib.pyplot as plt
import numpy as np
import h5py as h5
import ytree
import yt
import cPickle as pickle
import os
import math


# In[2]:


from matplotlib import rc, rcParams
rc('font', size=18)
rc('xtick', direction='in')
rc('ytick', direction='in')


# # Read halo merger trees

# In[3]:


trees = ytree.load('/storage/home/hcoda1/0/jw254/data/RS-RP/rockstar_halos/trees/tree_0_0_0.dat')

trees.add_alias_field('mass', 'Mvir')


# In[20]:


mrange = [1e8, 1e10]
halo_mmp = []
for tree in trees:
    if tree['mass'].in_units('Msun') < mrange[0] or tree['mass'].in_units('Msun') > mrange[1]:
        continue
    mmp = dict(center=[], mass=[], redshift=[], rvir=[])
    for prog in tree.pwalk():
        pos = yt.YTArray([prog['x'], prog['y'], prog['z']]) / trees.box_size
        mmp['center'].append(pos)
        mmp['mass'].append(prog['mass'].in_units('Msun'))
        mmp['redshift'].append(prog['redshift'])
        mmp['rvir'].append(prog['virial_radius'] / trees.box_size)
    mmp['center'] = yt.YTArray(mmp['center'])
    mmp['mass'] = yt.YTArray(mmp['mass'])
    mmp['redshift'] = yt.YTArray(mmp['redshift'])
    mmp['rvir'] = yt.YTArray(mmp['rvir'])
    halo_mmp.append(mmp)


# In[21]:


print halo_mmp[0]['rvir']


# # Read simulation redshifts

# In[6]:


pfn = []
redshifts = []
if os.path.exists('redshifts.dat'):
    lines = open('redshifts.dat').readlines()
    for l in lines:
        pfn.append(l.split(':')[0])
        redshifts.append(float(l.split('=')[-1]))
else:
    ts = yt.DatasetSeries('DD????/output_????')
    for ds in ts:
        redshifts.append(ds.current_redshift)
        pfn.append(ds.parameter_filename)
    
redshifts = np.array(redshifts)
pfn = np.array(pfn)
isort = redshifts.argsort().astype('int')[::-1]
redshifts = redshifts[isort]
pfn = pfn[isort]


# # Read halo properties

# In[22]:


print halo_mmp[0]['rvir']


# In[23]:


pfile = 'fesc.cpkl'
if os.path.exists(pfile):
    fp = open(pfile, 'rb')
    catalog = pickle.load(fp)
    fp.close()
else:
    catalog = []
    for fn in pfn:
        entry = {}
        fp = h5.File('fesc-data/p%s_fesc_halos.h5' % (fn.split('/')[1]), 'r')
        nhalos = len(fp.keys())
        if nhalos == 0:
            catalog.append(entry)
            fp.close()
            continue
        gp0 = fp.values()[0]
        avoid = ['Pop2_Stars', 'Pop3_Stars', 'fesc_bins', 'fesc_hist']
        vector_fields = ['center']
        # Create empty entry
        for f in gp0:
            if f not in avoid:
                if f in vector_fields:
                    entry[f] = np.zeros((nhalos,3))
                else:
                    entry[f] = np.zeros(nhalos)
        # Read the data
        i = 0
        for g in fp.itervalues():
            for f in g:
                if f not in avoid:
                    entry[f][i] = g[f].value
            i += 1
        catalog.append(entry)
        fp.close()
    # Serialize properties
    fp = open(pfile, 'wb')
    pickle.dump(catalog, fp)
    fp.close()


# # Link halo properties to merger tree nodes

# In[24]:


def find_nearest(array, value):
    return np.abs(array - value).argmin()


# In[25]:


print halo_mmp[0]['rvir']


# In[26]:


fields = catalog[-1].keys()
fields.remove('center')
fields.remove('rvir')
for halo in halo_mmp:
    nnode = len(halo['redshift'])
    for f in fields:
        halo[f] = np.zeros(nnode)
    for inode in range(nnode):
        ip = find_nearest(redshifts, halo['redshift'][inode])
        
        # dr = separation, R = radius of target halo, r = radii of all catalog halos
        dr = np.sqrt(((halo['center'][inode] - catalog[ip]['center'])**2).sum(1))
        R = halo['rvir'][inode]
        r = catalog[ip]['rvir'] * (1 + redshifts[ip]) / trees.box_size.in_units('kpc').v
        
        # Calculate the sphere-sphere intersection. The maximum is the match.
        # http://mathworld.wolfram.com/Sphere-SphereIntersection.html
        vol = np.pi * (R+r-dr)**2 * (dr**2 + 2*dr*r - 3*r**2 + 2*dr*R + 6*r*R - 3*R**2) / (12*dr)
        vol[dr > r+R] = 0.0  # No intersection
        vol[dr < R-r] = (4*np.pi/3) * r[dr < R-r]**3  # Complete intersection
        
        match = vol.argmax()
        rvir = catalog[ip]['rvir'][match] * (1 + redshifts[ip]) / trees.box_size.in_units('kpc').v
        # Check whether separation is within the virial radius
        if dr[match] >= rvir:
            continue
        # Add halo properties to mmp history
        for f in fields:
            halo[f][inode] = catalog[ip][f][match]
    # Calculate SFR (last 20 Myr) [Msun/yr]
    halo['SFR'] = halo['Mstar_pop2_young'] / 20e6
    halo['fesc'] = np.maximum(halo['fesc'], 1e-6)


# In[27]:


print halo['mass']


# # Save to file for plotting

# In[28]:


fp = h5.File('catalog.h5', 'w')
for i,halo in enumerate(halo_mmp):
    hname = "Halo%8.8d" % (i)
    gp = fp.create_group(hname)
    for k,v in halo.items():
        gp[k] = v
fp.close()


# In[29]:


1 / (halo_mmp[0]['redshift']+1)


# In[30]:


halo_mmp[0]['mass']


# In[31]:


len(halo_mmp)


# In[ ]:


fields = ['mass', 'Mstar', 'SFR', 'fesc', 'fgas', 'fstar']
log = [True, True, True, True, False, True]
ylabel = [r'M$_{\rm vir}$ [M$_\odot$]', r'M$_{\star}$ [M$_\odot$]', 'SFR [M$_\odot$/yr]',
          r'f$_{\rm esc}$', r'f$_{\rm gas}$', r'f$_\star$']
nhalos = len(halo_mmp)
for i in range(nhalos):
    if halo_mmp[i]['Mstar'][0] < 1: continue
    fig, ax = plt.subplots(6, 1, figsize=(8,16), sharex=True)
    plt.subplots_adjust(hspace=1e-3)
    for j in range(len(fields)):
        if log[j]:
            ax[j].semilogy(halo_mmp[i]['redshift'], halo_mmp[i][fields[j]], lw=3)
        else:
            ax[j].plot(halo_mmp[i]['redshift'], halo_mmp[i][fields[j]], lw=3)
        ax[j].set_ylabel(ylabel[j])
    ax[0].set_title('Halo %d' % (i))
    ax[-1].set_xlabel('Redshift')
    plt.savefig('halo%6.6d-evo.png' % (i))
# Out:
#   Cell In[50], line 61
#     print halo_mmp[0]['rvir']
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(halo_mmp[0]['rvir'])?

# %%
import os, sys, time
import yt
import healpy
from math import sqrt
import h5py as h5
import numpy as np
import yt.utilities.cosmology as co
from yt.units import mass_hydrogen

get_ipython().magic(u'matplotlib inline')
import matplotlib.pyplot as plt
import ytree
import yt
import os
import math


yt.enable_plugins()
yt.enable_parallelism()
comm = yt.communication_system.communicators[-1]
# Out:
# /tmp/ipykernel_1072405/3485574405.py:10: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic(u'matplotlib inline')
# yt : [INFO     ] 2025-04-27 19:25:52,811 Loading plugins from /storage/home/hcoda1/7/shardin31/.config/yt/my_plugins.py
# yt : [ERROR    ] 2025-04-27 19:25:52,822 Could not enable parallelism: mpi4py is not installed

# %%
a = ytree.load('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/arbor/arbor.h5')
a.field_list
# Out:
# ['scale_factor',
#  'uid',
#  'desc_scale',
#  'desc_uid',
#  'num_prog',
#  'pid',
#  'upid',
#  'desc_pid',
#  'phantom',
#  'sam_Mvir',
#  'mass',
#  'virial_radius',
#  'scale_radius',
#  'velocity_dispersion',
#  'mmp?',
#  'scale_of_last_MM',
#  'vmax',
#  'position_x',
#  'position_y',
#  'position_z',
#  'velocity_x',
#  'velocity_y',
#  'velocity_z',
#  'angular_momentum_x',
#  'angular_momentum_y',
#  'angular_momentum_z',
#  'spin_parameter',
#  'Breadth_first_ID',
#  'Depth_first_ID',
#  'Tree_root_ID',
#  'halo_id',
#  'Snap_idx',
#  'Next_coprogenitor_depthfirst_ID',
#  'Last_progenitor_depthfirst_ID',
#  'Last_mainleaf_depthfirst_ID',
#  'Tidal_Force',
#  'Tidal_ID',
#  'Rs_Klypin',
#  'Mvir_all',
#  'M200b',
#  'M200c',
#  'M500c',
#  'M2500c',
#  'Xoff',
#  'Voff',
#  'Spin_Bullock',
#  'b_to_a',
#  'c_to_a',
#  'A[x]',
#  'A[y]',
#  'A[z]',
#  'b_to_a(500c)',
#  'c_to_a(500c)',
#  'A[x](500c)',
#  'A[y](500c)',
#  'A[z](500c)',
#  'T_|U|',
#  'M_pe_Behroozi',
# ...

# %%
with h5.File('/storage/home/hcoda1/7/shardin31/p-jw254-0/Research/Powderday/powderday/parameter_files_renaissance/convenience_renaissance/fesc-only/RP/RedshiftOutput0041-fesc-only.h5', 'r') as file:
    #print(&quot;Keys: %s&quot; % file.keys())
    group_keys = list(file.keys())
    print(group_keys)
    
    # Getting the data
    Mstar_data = list(file['Mstar'])
    fesc_data = list(file['fesc'])
    center_data = list(file['center'])
    mass_data = list(file['mass'])
    print(fesc_data)
# Out:
# ['Mstar', 'Nesc', 'Ntot', 'center', 'fesc', 'mass']
# ...

# %%
nhalos = -1
start_halo = 0
healpix_level = 2
overwrite_fesc = False

data_dir = 'fesc-data'
if yt.is_root():
    if not os.path.exists('fesc-data'):
        os.mkdir(data_dir)
        
fn = '/storage/home/hcoda1/0/jw254/data/RS-RP/RD0041/RedshiftOutput0041'
if not os.path.exists(fn):
    raise RuntimeError("Dataset %s not found" % (fn))
ds = yt.load(fn)
# ds.add_particle_filter('p2')
# ds.add_particle_filter('p2_young')
# ds.add_particle_filter('p3_living')

# omega = dict(b=0.0449, m=ds.parameters['CosmologyOmegaMatterNow'],
#              l=ds.parameters['CosmologyOmegaLambdaNow'])
# dm_factor = (omega['m'] - omega['b']) / omega['m']
# rvir_factor = dm_factor**(-1./3)

# hfn = '/storage/home/hcoda1/0/jw254/data/RS-RP/RD0041/RedshiftOutput0041'
# #hfn = "rockstar_halos/halos_%s.0.bin" % (ds.directory)
# if not os.path.exists(hfn):
#     raise RuntimeError("Halo catalog %s not found" % (hfn))
# hds = yt.load(hfn)
# halos = hds.all_data()
# msort = halos['particle_mass'].argsort().v.astype('int')[::-1]
# if nhalos < 0:
#     nhalos = msort.size

# rvir_arr = []
# for ihalo in range(start_halo, nhalos):
#     ih = msort[ihalo]
#     rvir = (ds.quan(halos['virial_radius'][ih].in_cgs().v, 'cm') * rvir_factor).in_units('kpc').v
#     rvir_arr.append(rvir)
    #rvir_arr[ih] = (ds.quan(a['virial_radius'][ih].in_cgs().v, 'cm') * rvir_factor).in_units('kpc').v
    #rvir_arr[ih] = rvir[ih].in_units('kpc').v
# Out:
# yt : [INFO     ] 2025-04-27 20:30:04,241 Parameters: current_time              = 12.75658720606
# yt : [INFO     ] 2025-04-27 20:30:04,243 Parameters: domain_dimensions         = [512 512 512]
# yt : [INFO     ] 2025-04-27 20:30:04,244 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-04-27 20:30:04,245 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-04-27 20:30:04,245 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2025-04-27 20:30:04,246 Parameters: current_redshift          = 14.999999224523
# yt : [INFO     ] 2025-04-27 20:30:04,246 Parameters: omega_lambda              = 0.734
# yt : [INFO     ] 2025-04-27 20:30:04,247 Parameters: omega_matter              = 0.266
# yt : [INFO     ] 2025-04-27 20:30:04,247 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2025-04-27 20:30:04,247 Parameters: hubble_constant           = 0.71

# %%
omega = dict(b=0.0449, m=ds.parameters['CosmologyOmegaMatterNow'],
             l=ds.parameters['CosmologyOmegaLambdaNow'])
dm_factor = (omega['m'] - omega['b']) / omega['m']
rvir_factor = dm_factor**(-1./3)

# %%
hfn = '/storage/home/hcoda1/0/jw254/data/RS-RP/RD0041/RedshiftOutput0041'
#hfn = "rockstar_halos/halos_%s.0.bin" % (ds.directory)
if not os.path.exists(hfn):
    raise RuntimeError("Halo catalog %s not found" % (hfn))
hds = yt.load(hfn)
halos = hds.all_data()
print(halos['particle_mass'])
msort = halos['particle_mass'].argsort().value.astype('int')[::-1]
if nhalos < 0:
    nhalos = msort.size
# Out:
# yt : [INFO     ] 2025-04-28 00:02:24,403 Parameters: current_time              = 12.75658720606
# yt : [INFO     ] 2025-04-28 00:02:24,404 Parameters: domain_dimensions         = [512 512 512]
# yt : [INFO     ] 2025-04-28 00:02:24,405 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-04-28 00:02:24,406 Parameters: domain_right_edge         = [1. 1. 1.]
# yt : [INFO     ] 2025-04-28 00:02:24,407 Parameters: cosmological_simulation   = 1
# yt : [INFO     ] 2025-04-28 00:02:24,407 Parameters: current_redshift          = 14.999999224523
# yt : [INFO     ] 2025-04-28 00:02:24,407 Parameters: omega_lambda              = 0.734
# yt : [INFO     ] 2025-04-28 00:02:24,408 Parameters: omega_matter              = 0.266
# yt : [INFO     ] 2025-04-28 00:02:24,408 Parameters: omega_radiation           = 0.0
# yt : [INFO     ] 2025-04-28 00:02:24,408 Parameters: hubble_constant           = 0.71
# ...

# %%
rvir_arr = []
for ihalo in range(start_halo, nhalos):
    ih = msort[ihalo]
    rvir = (ds.quan(halos['virial_radius'][ih].in_cgs().value, 'cm') * rvir_factor).in_units('kpc').v
    rvir_arr.append(rvir)

# %%
trees = ytree.load('/storage/home/hcoda1/0/jw254/data/RS-RP/rockstar_halos/trees/tree_0_0_0.dat')

for i in range(0, a.size, 1):
    if a['stellar_mass'][i]!= 0:
        my_halo_center = a['position'][i].value
        redshift = ds.current_redshift
        # dr = separation, R = radius of target halo, r = radii of all catalog halos
        dr = np.sqrt(((my_halo_center - center_data)**2).sum(1))
        R = a['virial_radius'][i].value
        r = rvir_arr * (1 + redshift) / trees.box_size.in_units('kpc').v
        
        # Calculate the sphere-sphere intersection. The maximum is the match.
        # http://mathworld.wolfram.com/Sphere-SphereIntersection.html
        vol = np.pi * (R+r-dr)**2 * (dr**2 + 2*dr*r - 3*r**2 + 2*dr*R + 6*r*R - 3*R**2) / (12*dr)
        vol[dr > r+R] = 0.0  # No intersection
        vol[dr < R-r] = (4*np.pi/3) * r[dr < R-r]**3  # Complete intersection
        
        match = vol.argmax()
        rvir = rvir_arr[match] * (1 + redshift) / trees.box_size.in_units('kpc').v
        # Check whether separation is within the virial radius
        if dr[match] >= rvir:
            continue
#         print(fesc_data[match])
#         fcov = 1 - fesc_data[match]
#         print(fcov)
# Out:
# /tmp/ipykernel_977500/3836196252.py:1: DeprecationWarning: `magic(...)` is deprecated since IPython 0.13 (warning added in 8.1), use run_line_magic(magic_name, parameter_s).
#   get_ipython().magic(u'matplotlib inline')
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 17
#      15 dr = np.sqrt(((my_halo_center - center_data)**2).sum(1))
#      16 R = a['virial_radius'][i].value
# ---> 17 r = catalog[ip]['rvir'] * (1 + redshifts[ip]) / trees.box_size.in_units('kpc').v
#      19 # Calculate the sphere-sphere intersection. The maximum is the match.
#      20 # http://mathworld.wolfram.com/Sphere-SphereIntersection.html
#      21 vol = np.pi * (R+r-dr)**2 * (dr**2 + 2*dr*r - 3*r**2 + 2*dr*R + 6*r*R - 3*R**2) / (12*dr)
#
# NameError: name 'catalog' is not defined

# %%
import os, sys, time
import yt
import healpy
from p3lum import *
from math import sqrt
import h5py as h5
import numpy as np
import yt.utilities.cosmology as co
from yt.units import mass_hydrogen

yt.enable_plugins()
yt.enable_parallelism()
comm = yt.communication_system.communicators[-1]

nhalos = -1
start_halo = 0
healpix_level = 2
overwrite_fesc = False

data_dir = 'fesc-data'
if yt.is_root():
    if not os.path.exists('fesc-data'):
        os.mkdir(data_dir)
        
fn = sys.argv[-1]
if not os.path.exists(fn):
    raise RuntimeError("Dataset %s not found" % (fn))
ds = yt.load(fn)
ds.add_particle_filter('p2')
ds.add_particle_filter('p2_young')
ds.add_particle_filter('p3_living')

omega = dict(b=0.0449, m=ds.parameters['CosmologyOmegaMatterNow'],
             l=ds.parameters['CosmologyOmegaLambdaNow'])
dm_factor = (omega['m'] - omega['b']) / omega['m']
rvir_factor = dm_factor**(-1./3)

halo_file = "%s/p%s_fesc_halos.h5" % (data_dir, ds)
ascii_file = "%s/p%s_fesc_halos.txt" % (data_dir, ds)
if yt.is_root():
    fpa = open(ascii_file, "w")
    fpa.write("#%9s %10s %10s %10s %10s %10s %10s %10s\n" % \
              ("HaloNum", "Time[Myr]", "Mtotal", "Mstar", "M_young", "f_esc", "f_star", "f_gas"))
    fpa.write("#"*90 + "\n")


# Load halo catalog
hfn = "rockstar_halos/halos_%s.0.bin" % (ds.directory)
if not os.path.exists(hfn):
    raise RuntimeError("Halo catalog %s not found" % (hfn))
hds = yt.load(hfn)
halos = hds.all_data()
msort = halos['particle_mass'].argsort().v.astype('int')[::-1]
if nhalos < 0:
    nhalos = msort.size

# Get ionizing parameters
nion_mass = ds.parameters["StarClusterIonizingLuminosity"]
helium_ion = ds.parameters["StarClusterHeliumIonization"]

comm.barrier()
hfile_exists = os.path.exists(halo_file)
comm.barrier()

if yt.is_root():
    if hfile_exists and not overwrite_fesc:
        hf = h5.File(halo_file, "a")
    else:
        hf = h5.File(halo_file, "w")
else:
    if hfile_exists and not overwrite_fesc:
        hf = h5.File(halo_file, "r")

for ihalo in range(start_halo, nhalos):
    ih = msort[ihalo]
    halo_name = "Halo%8.8d" % (ihalo)
    if hfile_exists and not overwrite_fesc:
        if halo_name in hf.keys():
            print "%s already exists. Skipping." % (halo_name)
            continue

    if yt.is_root():
        hf.create_group(halo_name)

    # Create a set of points, corresponding to HEALPix pixel centers
    # that are r200 away from the center of mass
    nside = 2**healpix_level
    npix = 12 * nside**2
    pixels = healpy.pix2vec(nside, np.arange(npix), nest=True)
    pixels = np.array(pixels).T
    rvir = ds.quan(halos['virial_radius'][ih].in_cgs().v, 'cm') * rvir_factor
    center0 = ds.arr(halos['particle_position'][ih].in_cgs().v, 'cm')
    sp = ds.sphere(center0, rvir)
    center = sp.quantities.center_of_mass()
    pixels = rvir * pixels + center

    # Star particle number and total mass
    np3 = int(sp['p3_living', 'particle_ones'].sum())
    np2 = int(sp['p2', 'particle_ones'].sum())
    np2y = int(sp['p2_young', 'particle_ones'].sum())
    Mstar2 = sp['p2', 'particle_mass'].sum()
    Mstar2y = sp['p2_young', 'particle_mass'].sum()
    Mstar3 = sp['p3_living', 'particle_mass'].sum()
    Mstar = Mstar2 + Mstar3
    Mgas, Mdm = sp.quantities.total_mass()
    Mhalo = Mgas + Mdm

    # Delete existing data, if requested
    if overwrite_fesc and hfile_exists and yt.is_root():
        for k in hf[halo_name].keys():
            if k not in ["center", "rvir", "mass"]:
                del hf[halo_name][k]
    
    if yt.is_root():
        hf[halo_name]["NumberOfPop2Stars"] = np2
        hf[halo_name]["NumberOfPop3Stars"] = np3
        g2 = hf[halo_name].create_group("Pop2_Stars")
        g3 = hf[halo_name].create_group("Pop3_Stars")
 
    Ntot = 0.0
    Nesc = 0.0
    Nfesc = 100
    fesc_all = np.zeros(Nfesc+1)
    fesc_bins = np.linspace(0, 1, Nfesc+1)

    # Preload HI_Density
    trash = sp['H_p0_density']

    ##################
    # Pop III stars
    ##################
    for i in range(np3):
        star_name = "star%8.8d" % (i)
        starc = sp['p3_living', 'particle_position'][i]
        mass = sp['p3_living', 'particle_mass'][i]
        my_storage = {}
        for sto, j in yt.parallel_objects(range(npix), storage = my_storage):
            ray = ds.ray(starc, pixels[j,:])
            ray_length = np.sqrt(np.sum((starc - pixels[j,:]))**2)
            # Column density in ray segments
            dN = ray_length * ray['dts'] * ray['H_p0_number_density']
            sto.result_id = j
            sto.result = dN.sum()
        if yt.is_root():
            allN = []
            for j, val in sorted(my_storage.items()):
                allN.append(val)
            allN = ds.arr(allN)
            E, nion = pop3_lum(mass)
            # Photo-ionization cross section (Verner 1996)
            sigma_HI = ds.quan(5.475e-14 * (E[0] / 0.4298 - 1)**2 * \
                               (E[0] / 0.4298)**(-4.0185) * \
                               (1 + sqrt(E[0] / 14.13))**(-2.963), 'cm**2')
            tau = (allN * sigma_HI).in_units('dimensionless').v
            fesc = np.exp(-tau)
            fesc_avg = fesc.mean()
            ibins = np.searchsorted(fesc_bins, fesc)
            for j in range(npix):
                fesc_all[ibins[j]] += nion[0] / npix
            Nesc += fesc_avg * nion[0]
            Ntot += nion[0]
            sg = g3.create_group(star_name)
            sg['pos'] = starc.in_units('code_length')
            sg['mass'] = mass.in_units('Msun')
            sg['fesc'] = fesc
            sg['NHI'] = allN.in_units('1/cm**2')
            sg['fesc_avg'] = fesc_avg
            sg['Nesc'] = fesc_avg * nion[0]
            sg['Ntot'] = nion[0]

    ########################
    # Metal-enriched stars
    ########################
    for i in range(np2y):
        star_name = "star%8.8d" % (i)
        starc = sp['p2_young', 'particle_position'][i]
        mass = sp['p2_young', 'particle_mass'][i]
        my_storage = {}
        for sto, j in yt.parallel_objects(range(npix), storage = my_storage):
            ray = ds.ray(starc, pixels[j,:])
            ray_length = np.sqrt(np.sum((starc - pixels[j,:]))**2)
            # Column density in ray segments
            dN = ray_length * ray['dts'] * ray['H_p0_number_density']
            sto.result_id = j
            sto.result = dN.sum()
        if yt.is_root():
            allN = []
            for j, val in sorted(my_storage.items()):
                allN.append(val)
            allN = ds.arr(allN)
            E, nion = pop2_lum(mass, nion_mass, helium_ion=helium_ion)
            # Photo-ionization cross section (Verner 1996)
            sigma_HI = ds.quan(5.475e-14 * (E[0] / 0.4298 - 1)**2 * \
                               (E[0] / 0.4298)**(-4.0185) * \
                               (1 + sqrt(E[0] / 14.13))**(-2.963), 'cm**2')
            tau = (allN * sigma_HI).in_units('dimensionless').v
            fesc = np.exp(-tau)
            fesc_avg = fesc.mean()
            ibins = np.searchsorted(fesc_bins, fesc)
            for j in range(npix):
                fesc_all[ibins[j]] += nion[0] / npix
            Nesc += fesc_avg * nion[0]
            Ntot += nion[0]
            sg = g2.create_group(star_name)
            sg['pos'] = starc.in_units('code_length')
            sg['mass'] = mass.in_units('Msun')
            sg['fesc'] = fesc
            sg['NHI'] = allN.in_units('1/cm**2')
            sg['fesc_avg'] = fesc_avg
            sg['Nesc'] = fesc_avg * nion[0]
            sg['Ntot'] = nion[0]
            print "Ray traced %5d out of %5d" % (i, np2y)

    # Write halo properties to file
    if yt.is_root():
        hf[halo_name]["Mstar_pop2"] = Mstar2.in_units('Msun')
        hf[halo_name]["Mstar_pop2_young"] = Mstar2y.in_units('Msun')
        hf[halo_name]["Mstar_pop3"] = Mstar3.in_units('Msun')
        hf[halo_name]["Mstar"] = Mstar.in_units('Msun')
        hf[halo_name]["Nesc"] = Nesc
        hf[halo_name]["Ntot"] = Ntot
        if Ntot > 0:
            fesc = Nesc / Ntot
        else:
            fesc = -1
        hf[halo_name]["fesc"] = fesc
        hf[halo_name]["fesc_bins"] = fesc_bins
        hf[halo_name]["fesc_hist"] = fesc_all
        hf[halo_name]["rvir"] = rvir.in_units('kpc').v
        hf[halo_name]["mass"] = Mhalo.in_units('Msun').v
        hf[halo_name]["fgas"] = Mgas / Mhalo
        hf[halo_name]["fstar"] = Mstar / Mhalo
        hf[halo_name]["center"] = center

        print "Halo %3.3d: Mtot = %s, Mstar = %s, fesc = %10.4f\n" % \
            (ihalo, Mhalo.in_units('Msun'), Mstar.in_units('Msun'), fesc)

        fpa.write("%10d %10.4g %10.4g %10.4g %10.4g %10.4f %10.4g %10.4g\n" % \
                      (ihalo, ds.current_time.in_units('Myr'),
                       Mhalo.in_units('Msun'), Mstar.in_units('Msun').v,
                       Mstar2y.in_units('Msun').v, fesc, Mstar/Mhalo, Mgas/Mhalo))
    
comm.barrier()
if yt.is_root():
    hf.close()
    fpa.close()
else:
    if hfile_exists and not overwrite_fesc:
        hf.close()
